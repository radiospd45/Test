# %%
import pandas as pd

# %%
df= pd.read_excel('기념품_seoul_2016-01-01_2022-05-16.xlsx')
df.loc[~df['dept'].str.contains('소방서')&df['title'].str.contains('구매')]
# Out:
#                                                   title  \
# 1                        국제 교류 협력 증진을 위한 전통기념품 구매 비용 지급
# 2                        국제 교류 협력 증진을 위한 전통기념품 구매 비용 지급
# 4                                      산하공원 프로그램 기념품 구매
# 5                           물품검사(수)조서(산하공원 프로그램 기념품 구매)
# 7                                   외빈 기념품 포장물품 구매비용 지급
# ...                                                 ...
# 3899                                 시의회 방문기념품 구매(손목시계)
# 3906  물 품 검 사 (수) 조 서 (2016 붉은 원숭이를 찾아라! 연장 운영관련 기념품...
# 3907                   2016 붉은 원숭이를 찾아라! 연장 운영관련 기념품 구매
# 3912                                 시의회 방문기념품 구매(미용세트)
# 3919                         물품 대금 지급-한강공원 방문 기념품 제작 구매
#
#                                                 URL        date  \
# 1     https://opengov.seoul.go.kr/sanction/25977766  2022-05-16
# 2     https://opengov.seoul.go.kr/sanction/25975944  2022-05-16
# 4     https://opengov.seoul.go.kr/sanction/25952534  2022-05-11
# ...
